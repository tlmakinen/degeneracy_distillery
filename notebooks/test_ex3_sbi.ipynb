# %%
# %cd /Users/lucas/repositories/degeneracy_distillery/
# Out:
# /Users/lucas/repositories/degeneracy_distillery
# /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
pwd
# Out:
# '/Users/lucas/repositories/degeneracy_distillery'

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from pyoperon.sklearn import SymbolicRegressor
import multiprocessing
import csv
from sklearn.metrics import r2_score
import string
import sys,os
import sympy
import scipy

# ESR is optional - install separately if needed
try:
    import esr.generation.generator
except ImportError:
    print("Warning: ESR not installed. Install with: git clone https://github.com/DeaglanBartlett/ESR.git && pip install -e ESR")

import jax
import jax.numpy as jnp

from tqdm import tqdm as tq

# Add package to path - works with new directory name
sys.path.insert(0, '../degeneracy_distillery')

# %%
pwd
# Out:
# '/Users/lucas/repositories/degeneracy_distillery'

# %%
# from postprocessing_utils import load_and_process_data, process_ensemble_rotation

# Import preprocessing (rotations, data loading)
from preprocessing_utils import (
    load_and_process_data,
    process_ensemble_rotation,
    flatten_with_numerical_jacobian,
    batch_flatten_fisher,
    rotate_coords,
    load_and_process_data,
    weighted_std
)

# Import postprocessing (SR optimization)
from postprocessing_utils import (
    lossfn_jac_jax,
    get_component,
    get_pruned_expressions,
    get_pruned_expressions_final,
    check_flattening,
    make_check_flattening_fn,
)

# Create loss function
# _lossfn = lambda a: lossfn_jac_jax(
#     a, all_pars, all_fns, all_linear_pars, all_linear_inds,
#     X=X, Fs=Fs, n_params=n_params, delta=0.2, alpha=1.5
# )

# Option 1: Load and process in one call
data = load_and_process_data(
    datapath="",
    filename="/Users/lucas/repositories/degeneracy_distillery/data/sbi-toy-problem.npz",
      #/Users/lucas/repositories/degen_discovery/simple_problems/flattened_coords_little_sigma.npz",
    num_samps=1000,
    process_ensemble=True,  # <-- enables full processing
    n_d=1.0,
    verbose=True,
    y_reference_index=None,
    use_var=True
)

# Access results directly:
y = data['y']           # Weighted average outputs (masked)
y_std = data['y_std']   # Weighted std (masked)
dy = data['dy']         # Weighted average Jacobian (masked)
dy_sr = data['dy_sr']   # Weighted average rotated Jacobian
Fs = data['Fs']         # Weighted average Fisher
X = data['X']           # Parameters (masked)

norm_factor = data['norm_factor']

n_params = X.shape[-1]

# Option 2: Two-step process (more control)
# data = load_and_process_data(datapath="./", filename="fake_cmb_flatten_03_09_sum.npz", process_ensemble=False)
# result = process_ensemble_rotation(
#     datafile=data['datafile'],
#     randidx=data['randidx'],
#     Favg=data['Favg'],
#     best_model_idx=data['best_model_idx'],
#     n_d=1.0
# )
# Out:
# best model 2
# Network 0: y.min() = -0.379654, weight = 1147.9
# thetastar [0.47009522 0.4685102  0.49163964]
# using var F
#   Shapes: y=(1000, 3), X=(1000, 3)
# Network 1: y.min() = -0.101417, weight = 1047.8
# thetastar [0.47009522 0.4685102  0.49163964]
# using var F
#   Shapes: y=(1000, 3), X=(1000, 3)
# Network 2: y.min() = -0.413905, weight = 1223.0
# thetastar [0.47009522 0.4685102  0.49163964]
# using var F
#   Shapes: y=(1000, 3), X=(1000, 3)
# Network 3: y.min() = -0.054899, weight = 942.6
# thetastar [0.47009522 0.4685102  0.49163964]
# using var F
#   Shapes: y=(1000, 3), X=(1000, 3)
# Network 4: y.min() = -0.078700, weight = 1031.7
# thetastar [0.47009522 0.4685102  0.49163964]
# using var F
#   Shapes: y=(1000, 3), X=(1000, 3)
#
# Ensemble shapes: dys=(5, 1000, 3, 3), ys=(5, 1000, 3)

# %%
# create scatterplot to see how y responds to X

fig, axs = plt.subplots(n_params, n_params, figsize=(11,11))

skip=10

for i in range(X.shape[-1]):
    for j in range(y.shape[-1]):
        
        # row, column
        axs[i,j].errorbar(X[::skip,i], y[::skip, j], yerr=y_std[::skip, j], label='', fmt='o', markersize=1)

        axs[i,j].set_xlabel(r"$X_%d$"%(i))
        axs[i,j].set_ylabel(r"$y_%d$"%(j))

plt.tight_layout()
plt.show()

# %%
y[0]
# Out:
# array([0.5458598, 0.1169265, 1.7887526], dtype=float32)

# %%
np.cov(y, rowvar=False).shape
# Out:
# (3, 3)

# %%
plt.imshow(dy.std(0))
plt.colorbar()
plt.title('original Jacobian variance')
plt.xlabel("$X$")
plt.ylabel("$y$")
# Out:
# Text(0, 0.5, '$y$')

# %%
plt.imshow(dy_sr.std(0))
plt.colorbar()
plt.title('transformed Jacobian variance')
plt.xlabel("$X$")

plt.ylabel("$y$")
# Out:
# Text(0, 0.5, '$y$')

# %%
plt.imshow(dy_sr.var(0) > (dy_sr.var(0).mean()))
plt.colorbar()
plt.title('transformed Jacobian variance above <var>')
plt.xlabel("$X$")
plt.ylabel("$y$")
# Out:
# Text(0, 0.5, '$y$')

# %%
plt.imshow(dy.std(0) > (dy.std(0).mean()))
plt.colorbar()
plt.title('original Jacobian variance above <var>')
plt.xlabel("$X$")
plt.ylabel("$y$")
# Out:
# Text(0, 0.5, '$y$')

# %%
# foo = dy_sr / np.sqrt(0.5)
plt.imshow(jax.vmap(flatten_with_numerical_jacobian)(dy, Fs).mean(0))
plt.colorbar()

# %%
plt.scatter(data['ys'][0, ::2, 0], np.average(data['ys'][1:, ::2, 0], axis=0, \
                            weights=(data['ensemble_weights'][1:])), s=3) 

plt.plot(data['ys'][0, ::2, 0],data['ys'][0, ::2, 0], c='k')
plt.xlabel(r"$\eta_{0,j=0}$")
plt.ylabel(r"$\langle\eta_{0,j}\rangle$")
# Out:
# Text(0, 0.5, '$\\langle\\eta_{0,j}\\rangle$')

# %%
fig,axs = plt.subplots(1,2)
axs = axs.flatten()

for i,ax in enumerate(axs):
    ax.hist(((data['ys'] - y) / y_std)[:, :, i].flatten(), density=True)
    ax.hist(np.random.normal(size=(2000,)).flatten(), histtype='step', density=True)

# %%
(np.sqrt(np.linalg.det(Fs).mean()))
# Out:
# 0.028873753

# %% [markdown]
# # try out symbolic fitting code

# %%
from sr_utils import fit_and_analyze_sr

# Split your data
# halfx = X.shape[0] // 2
# X_train, X_val = X[:halfx], X[halfx:]
# y_train, y_val = y[:halfx], y[halfx:]
# Fs_train, Fs_val = Fs[:halfx], Fs[halfx:]
# dy_sr_train, dy_sr_val = dy_sr[:halfx], dy_sr[halfx:]
# y_std_train, y_std_val = y_std[:halfx], y_std[halfx:]
# ... same for other arrays

# Run complete pipeline
parent_dir = './example_3/'

# Simple! Just pass your full arrays
mdl_coords, frob_coords, analysis, split_data = fit_and_analyze_sr(
    X, y, y_std, dy_sr, Fs,
    parent_dir=parent_dir,
    n_params=3,
    allowed_symbols='add,mul,pow,constant,variable,exp,sqrt,log',  # no log
    max_length=20,              # shorter equations
    time_limit=20,             # 5 minutes per component
    objectives=['rmse', 'length'],  # RMSE instead of R2
    equation_set='pareto'
)

print("Best MDL coordinates:", mdl_coords)
print("Best Frob coordinates:", frob_coords)
# Out:
# ============================================================
# Fitting component 1 of 3 (index 0)
# ============================================================
# X train shape: (500, 3), y train shape: (500,)
# Fitting...
# Done!
# Best model: (0.54 + ((-1.26) * (0.32 * X2)))
# Stats: {'model_length': 1, 'model_complexity': 3, 'generations': 532, 'evaluation_count': 0, 'residual_evaluations': 3475435, 'jacobian_evaluations': 2212655, 'random_state': 2345}
# Outputting 20 individuals on Pareto front
# Outputting 2000 individuals in population
#
# ============================================================
# Fitting component 2 of 3 (index 1)
# ============================================================
# X train shape: (500, 3), y train shape: (500,)
# Fitting...
# Done!
# Best model: (0.04 + (0.89 * (0.52 * X2)))
# Stats: {'model_length': 1, 'model_complexity': 3, 'generations': 496, 'evaluation_count': 0, 'residual_evaluations': 3447760, 'jacobian_evaluations': 2245164, 'random_state': 2345}
# Outputting 16 individuals on Pareto front
# Outputting 2000 individuals in population
#
# ============================================================
# Fitting component 3 of 3 (index 2)
# ============================================================
# X train shape: (500, 3), y train shape: (500,)
# Fitting...
# Done!
# Best model: (1.94 + ((-1.18) * (1.29 * X2)))
# Stats: {'model_length': 1, 'model_complexity': 3, 'generations': 590, 'evaluation_count': 0, 'residual_evaluations': 3721285, 'jacobian_evaluations': 2378879, 'random_state': 2345}
# Outputting 18 individuals on Pareto front
# Outputting 2000 individuals in population
#
# ============================================================
# Analysing component 1 of 3 (index 0)
# ============================================================
# Loading equations from: both pareto.csv and final_population.csv
#   Pareto: 20 equations, Population: 1000 equations
# 656 equations below complexity threshold 14
# Component 1:   0%|          | 0/656 [00:00<?, ?it/s]
#   Warning: Failed to process equation 0: (0.543280 + ((-1.262878) * (0.323398 * X2)))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
# Component 1:   0%|          | 1/656 [00:01<17:28,  1.60s/it]
#   Warning: Failed to process equation 1: (5.696276 + ((-5.155651) * exp((0.076193 * X2))))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 2: (0.506041 + ((-0.549316) * ((0.756723 * X2) + ((-0.145521) * X3))))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
# Component 1:   0%|          | 3/656 [00:02<07:00,  1.55it/s]
#   Warning: Failed to process equation 3: (0.545875 + (0.788675 * (exp(((-0.386474) * X3)) * ((-0.635951) * X2))))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 4: ((-0.672667) + (1.169642 * (((0.000419 * X3) ^ (0.048523 * X2)) + (0.098277 * X1))))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
# Component 1:   1%|          | 5/656 [00:02<04:02,  2.68it/s]
#   Warning: Failed to process equation 5: ((-1.631235) + (2.127090 * sqrt((((0.000348 * X3) ^ (0.048523 * X2)) + (0.098277 * X1)))))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 6: ((-0.000000) + (1.000000 * (((0.430787 + (0.109521 * X3)) + ((-0.405536) * X2)) + (0.108585 * X1))))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
# Component 1:   1%|          | 6/656 [00:03<03:34,  3.03it/s]
#   Warning: Failed to process equation 7: ((-0.000409) + (1.001457 * (log((((0.143709 * X3) + ((-0.535406) * X2)) + 1.533389)) + (0.107223 * X1))))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation
* X2))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 151: exp(((-1.5716745853) * X2))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 152: 0.3821753860
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
# Component 1:  23%|██▎       | 152/656 [00:09<00:18, 26.88it/s]
#   Warning: Failed to process equation 153: (log((exp(((2.3895144463 * X2) + (0.1703056544 * X1))) + (((27.6135807037 * X3) + ((-114.8922042847) * X2)) + 302.5439453125))) + (0.1025520712 * X1))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 154: ((log(((0.4426498711 * X2) + (1.5453459024 + ((-0.2661092579) * X3)))) + (((-0.6786589026) * X2) + (0.2728343010 * X3))) + (0.1070376188 * X1))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 155: (log(((((-0.9209988713) * X2) + (0.5459471345 + (0.1431760639 * X3))) + exp((0.3233982623 * X2)))) + (0.1070981845 * X1))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 156: ((sqrt((((-0.1274971813) * X2) + (0.1894293875 + (0.0868509635 * X3)))) + ((-0.2476156354) * X2)) + (0.1070470363 * X1))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 157: ((0.4005831182 + ((((-0.4021057785) * X2) + (0.1071433499 * X3)) + (0.1061702743 * X1))) ^ 0.9072539806)
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 158: (log((((-0.5354166031) * X2) + (1.5333889723 + (0.1437008977 * X3)))) + (0.1073830500 * X1))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
# Component 1:  24%|██▍       | 158/656 [00:09<00:18, 27.28it/s]
#   Warning: Failed to process equation 159: (((0.4307858050 + (0.1095216498 * X3)) + ((-0.4109310210) * X2)) + (0.1071302518 * X1))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 160: sqrt((((0.0007680453 * X3) ^ (0.0485228822 * X2)) + (0.0982773602 * X1)))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 161: (((0.0007680453 * X3) ^ (0.0485228822 * X2)) + (0.1027517915 * X1))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 162: sqrt(((0.0005332995 * X3) ^ (0.0096173678 * X2)))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 163: ((0.0004192732 * X3) ^ (0.0485228822 * X2))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 164: exp(((-1.5823944807) * X2))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
#   Warning: Failed to process equation 165: 0.3792675734
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
# Component 1:  25%|██▌       | 167/656 [00:09<00:28, 17.31it/s]
#   Warning: Failed to process equation 166: (log((exp(((2.3895144463 * X2) + (0.2004137486 * X1))) + (((28.5148677826 * X3) + ((-118.5435333252) * X2)) + 308.3324584961))) + (0.1025520712 * X1))
#   Error: sub got incompatible shapes for broadcasting: (3, 3), (6, 6).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 16
#      13 parent_dir = './example_3/'
#      15 # Simple! Just pass your full arrays
# ---> 16 mdl_coords, frob_coords, analysis, split_data = fit_and_analyze_sr(
#      17     X, y, y_std, dy_sr, Fs,
#      18     parent_dir=parent_dir,
#      19     n_params=6,
#      20     allowed_symbols='add,mul,pow,constant,variable,exp,sqrt,log',  # no log
#      21     max_length=20,              # shorter equations
#      22     time_limit=20,             # 5 minutes per component
#      23     objectives=['rmse', 'length'],  # RMSE instead of R2
#      24     equation_set='both'
#      25 )
#      27 print("Best MDL coordinates:", mdl_coords)
#      28 print("Best Frob coordinates:", frob_coords)
#
# File ~/repositories/degeneracy_distillery/src/sr_utils.py:987, in fit_and_analyze_sr(X, y, y_std, dy_sr, Fs, n_params, components_to_fit, parent_dir, test_size, random_state, shuffle, slice_fisher, **sr_kwargs)
#     980 fit_symbolic_regression(
#     981     X_train, y_train, y_std_train,
#     982     components_to_fit, parent_dir,
#     983     **fit_kwargs
#     984 )
#     986 # Analyze results on validation set
# --> 987 mdl_coords, frob_coords, analysis = analyze_equations(
#     988     X_val, y_val, y_std_val, dy_sr_val, Fs_val,
#     989     n_params, components_to_fit, parent_dir,
#     990     max_complexity_thresh=max_complexity_thresh,
#     991     equation_set=equation_set
#     992 )
#     994 # Package split data for return
#     995 split_data = {
#     996     'X_train': X_train,
#     997     'X_test': X_val,
#    (...)
#    1008     'slice_fisher': slice_fisher,
#    1009 }
#
# File ~/repositories/degeneracy_distillery/src/sr_utils.py:686, in analyze_equations(X, y, y_std, dy_sr, Fs, n_params, components_to_fit, parent_dir, max_complexity_thresh, equation_set, verbose)
#     684 for j, eq in enumerate(tqdm(eqs, desc=f"Component {i+1}")):
#     685     try:
# --> 686         c, latex, logL, DL, frobloss = compute_DL(
#     687             eq, idx, X, y, y_std, dy_sr, Fs, n_params
#     688         )
#     689         all_complexity[j] = c
#     690         all_latex[j] = latex
#
# File ~/repositories/degeneracy_distillery/src/sr_utils.py:310, in compute_DL(eq, component_idx, X, y, y_std, dy_sr, Fs, n_params)
#     308 all_x = list(sympy.symbols(all_x, real=True))
#     309 all_b = list(sympy.symbols(param_list, real=True))
# --> 310 eq_jax = sympy.lambdify(all_b + all_x, expr, modules=["jax"])
#     312 # Define loss function (negative log-likelihood)
#     313 def myloss(p):
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/sympy/utilities/lambdify.py:878, in lambdify(args, expr, modules, printer, use_imps, dummify, cse, docstring_limit)
#     876 else:
#     877     cses, _expr = (), expr
# --> 878 funcstr = funcprinter.doprint(funcname, iterable_args, _expr, cses=cses)
#     880 # Collect the module imports from the code printers.
#     881 imp_mod_lines = []
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/sympy/utilities/lambdify.py:1141, in _EvaluatorPrinter.doprint(self, funcname, args, expr, cses)
#    1139     cses = zip(subvars, subexprs)
#    1140 else:
# -> 1141     argstrs, expr = self._preprocess(args, expr)
#    1143 # Generate argument unpacking and final argument list
#    1144 funcargs = []
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/sympy/utilities/lambdify.py:1209, in _EvaluatorPrinter._preprocess(self, args, expr)
#    1207     s = str(arg)
#    1208 elif isinstance(arg, Basic) and arg.is_symbol:
# -> 1209     s = self._argrepr(arg)
#    1210     if dummify or not self._is_safe_ident(s):
#    1211         dummy = Dummy()
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/sympy/printing/codeprinter.py:156, in CodePrinter.doprint(self, expr, assign_to)
#     153 expr = _handle_assign_to(expr, assign_to)
#     155 # Remove re(...) nodes due to UnevaluatedExpr.is_real always is None:
# --> 156 expr = self._handle_UnevaluatedExpr(expr)
#     158 # keep a set of expressions that are not strictly translatable to Code
#     159 # and number constants that must be declared and initialized
#     160 self._not_supported = set()
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/sympy/printing/codeprinter.py:116, in CodePrinter._handle_UnevaluatedExpr(self, expr)
#     115 def _handle_UnevaluatedExpr(self, expr):
# --> 116     return expr.replace(re, lambda arg: arg if isinstance(
#     117         arg, UnevaluatedExpr) and arg.args[0].is_real else re(arg))
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/sympy/core/basic.py:1575, in Basic.replace(self, query, value, map, simultaneous, exact)
#    1412 """
#    1413 Replace matching subexpressions of ``self`` with ``value``.
#    1414
#    (...)
#    1571
#    1572 """
#    1574 try:
# -> 1575     query = _sympify(query)
#    1576 except SympifyError:
#    1577     pass
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/sympy/core/sympify.py:526, in _sympify(a)
#     500 def _sympify(a):
#     501     """
#     502     Short version of :func:`~.sympify` for internal usage for ``__add__`` and
#     503     ``__eq__`` methods where it is ok to allow some things (like Python
#    (...)
#     524
#     525     """
# --> 526     return sympify(a, strict=True)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/sympy/core/sympify.py:366, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     364         return a
#     365     else:
# --> 366         raise SympifyError(a)
#     368 if isinstance(a, CantSympify):
#     369     raise SympifyError(a)
#
# KeyboardInterrupt:

# %%
# Out:
# 2000

# %%
analysis.keys()
# Out:
# dict_keys(['latex', 'equations', 'frobloss', 'DL', 'logL', 'complexity', 'ibest_mdl', 'ibest_frob'])

# %%
analysis['logL'][4]
# Out:
# array([22371.70703125, 22523.42773438, 12044.37890625,  8081.15527344,
#         6162.80957031,  4840.21191406,  1557.39160156,     0.        ])

# %%
analysis['latex'][1]
# Out:
# ['X_{3} b_{1} b_{2} + b_{0}',
#  'b_{0} + b_{1} e^{X_{3} b_{2}}',
#  'b_{0} + b_{1} \\left(X_{1} b_{2} + X_{3} b_{3}\\right)',
#  'b_{0} + b_{1} \\left(X_{3} b_{2}\\right)^{e^{X_{1} b_{3}}}',
#  'b_{0} + b_{1} \\left(X_{1} b_{2} + X_{2} b_{3} + X_{3} b_{4}\\right)',
#  'b_{0} + b_{1} \\left(X_{2} b_{2} + X_{3} b_{3}\\right)^{e^{X_{1} b_{4}}}',
#  'b_{0} + b_{1} \\left(X_{1} b_{4} + X_{2} b_{2} + X_{3} b_{3} + X_{5} b_{5}\\right)',
#  'b_{0} + b_{1} \\left(X_{6} b_{5} + \\left(X_{2} b_{2} + X_{3} b_{3}\\right)^{e^{X_{1} b_{4}}}\\right)',
#  'b_{0} + b_{1} \\left(X_{1} b_{6} + X_{2} b_{2} + X_{3} b_{3} + X_{6} b_{4} + b_{5}\\right)']

# %%
# Access test data for further analysis
X_test = split_data['X_test']
y_test = split_data['y_test']
Fs_test = split_data['Fs_test']
y_std_test = split_data['y_std_test']
dy_sr_test = split_data['dy_sr_test']

# %%
Fs.shape, X.shape, y.shape, y_std.shape, dy_sr.shape
# Out:
# ((4000, 6, 6), (4000, 6), (4000, 6), (4000, 6), (4000, 6, 6))

# %%
# components_to_fit = [0,1]

# Access the best equation indices for component 0
ibest_mdl = analysis['ibest_mdl'][0]    # index of best MDL equation
ibest_frob = analysis['ibest_frob'][0]  # index of best Frob equation

# Get the actual equations at those indices
best_mdl_eq = analysis['equations'][0][ibest_mdl]
best_frob_eq = analysis['equations'][0][ibest_frob]

# Access other metrics at those indices
mdl_complexity = analysis['complexity'][0][ibest_mdl]
frob_complexity = analysis['complexity'][0][ibest_frob]



n_components = 6

both_comp_latex = []
both_comp_eqs = []
both_comp_frobloss = []
both_comp_logL = []
both_comp_DL = []


max_complexity_thresh = 15

for i in range(n_components):

    idx = i


    # Access the best equation indices for component 0
    ibest_mdl = analysis['ibest_mdl'][i]    # index of best MDL equation
    ibest_frob = analysis['ibest_frob'][i]  # index of best Frob equation

    # Get the actual equations at those indices
    best_mdl_eq = analysis['equations'][i][ibest_mdl]
    best_frob_eq = analysis['equations'][i][ibest_frob]

    # Access other metrics at those indices
    mdl_complexity = analysis['complexity'][i][ibest_mdl]
    frob_complexity = analysis['complexity'][i][ibest_frob]
    


    fig, ax1 = plt.subplots(1, 1, figsize=(7,4), sharex=True)
    cm = plt.get_cmap('Set1')
    ax2 = ax1.twinx()
    
    #ax1.plot(complexity, pareto_DL, marker='.', color=cm(0), markersize=5, )
    # ax2.plot(complexity, pareto_logL, marker='.', color=cm(1), markersize=5, ls=':')
    ax1.plot(analysis['complexity'][i], analysis['logL'][i], marker='.', color=cm(0), markersize=5, )
    ax2.plot(analysis['complexity'][i], analysis['frobloss'][i], marker='.', color=cm(1), markersize=5, ls=':')


    #ax1.set_ylabel('Change in Description Length')
    # ax2.set_ylabel('Change in Negative log-likelihood')
    ax1.set_ylabel('Change in Negative log-likelihood')
    ax2.set_ylabel('Change in Frobenius Norm Loss')
    ax1.yaxis.label.set_color(cm(0))
    ax1.tick_params(axis='y', colors=cm(0))
    ax2.spines['left'].set_color(cm(0))

    ax2.yaxis.label.set_color(cm(1))
    ax2.tick_params(axis='y', colors=cm(1))
    ax2.spines['right'].set_color(cm(1))

    ax1.set_yscale('symlog')
    ax2.set_yscale('symlog')
    ax1.set_ylim(0, None)
    ax2.set_ylim(0, None)

    pareto_latex = analysis['latex'][i]
    #ax1.axvline(complexity[pysr_ibest], color=cm(2), ls=':', label=r'Score: $y = %s$'%all_latex[pysr_ibest])
    ax1.axvline(analysis['complexity'][i][ibest_mdl], color=cm(3), ls='--', label=r'MDL: $y = %s$'%pareto_latex[ibest_mdl])
    ax1.axvline(analysis['complexity'][i][ibest_frob], color=cm(4), ls='--', label=r'Frob: $y = %s$'%pareto_latex[ibest_frob])

    ax1.legend()
    plt.title("component %d"%(idx + 1))
    plt.show()
    #fig.savefig('function_ranking.png', bbox_inches='tight', facecolor='white')

# %%
mdl_coords
# Out:
# ['(0.198915 + (0.740551 * (((sqrt((0.997869 * X4)) + ((-0.254262) * X5)) + (0.231963 * X2)) + ((-0.131264) * X6))))',
#  '((-0.000005) + (0.999998 * ((((0.146357 * X2) + (0.297831 * X3)) + ((-0.113143) * X6)) + (0.335804 + ((-0.177085) * X1)))))',
#  '((-0.043820) + (1.062336 * ((0.385171 + ((0.001209 * X3) ^ (0.474258 * X4))) + (((-0.113036) * X5) + ((-0.101597) * X6)))))',
#  '((-0.070241) + (1.024071 * ((sqrt((5.114736 * X4)) + ((6.283185 * X3) * (0.040789 * X1))) + ((-0.888934) * X4))))',
#  '(0.000000 + (1.000001 * (((0.303160 + ((-0.296884) * X4)) + (0.174063 * X2)) + ((0.113381 * X1) + (0.132586 * X5)))))',
#  '((-0.000004) + (0.999999 * (((((0.133432 * X3) + (0.226473 * X6)) + (0.168353 * X2)) + ((-0.266463) * X4)) + 0.262993)))']

# %% [markdown]
# # post-process SR expressions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pwd
# Out:
# '/Users/lucas/repositories/degeneracy_distillery'

# %%
# Import postprocessing (SR optimization)
from postprocessing_utils import (
    lossfn_jac_jax,
    get_component,
    get_pruned_expressions,
    get_pruned_expressions_final,
    check_flattening,
    make_check_flattening_fn,
    get_Q_jax, construct_M
)

# %% [markdown]
# ### demo

# %%
all_pars = []
all_linear_pars = []
all_fns = []
all_linear_inds = []
all_param_dicts = []
all_xs = []
all_bs = []

all_expr = []

all_linear_labels = []

for i in range(n_params):
    # lab, expr, prs, _x, _b, eq_fn, oldexpr, nodes = get_component(mdl_coordinates[i], i)

    lab, expr, prs, linear_prs, _x, _b, eq_fn, param_dict, linear_inds = get_component(mdl_coords[i], i, X=X, module="jax")
    all_pars.append(prs)
    all_linear_pars.append(linear_prs)
    all_fns.append(eq_fn)
    all_xs.append(_x)
    all_bs.append(_b)
    all_linear_inds.append(linear_inds)
    all_param_dicts.append(param_dict)
    all_expr.append(expr)

    all_linear_labels.append([_b[l] for l in linear_inds])

# %%
import numpy as np
from scipy.optimize import minimize

def sparse_rotation_loss(A_flat, M, lambda_ortho=1.0, alpha=1.0):
    """
    A_flat: Flattened rotation matrix A (size N*N)
    M:      Coefficient matrix (size N*T)
    lambda_ortho: Weight for orthogonality constraint
    alpha:  Scaling factor for log-cosh (controls steepness)
    """
    # 1. Reshape A back to square matrix
    dim = int(np.sqrt(len(A_flat)))
    A = A_flat.reshape((dim, dim))
    # A = get_Q_jax(A)
    
    # 2. Calculate Rotated Factors (y_pred components)
    # y_pred = A @ M (The projection we want to be sparse)
    transformed_M = A @ M
    
    # 3. Sparsity Loss (Log-Cosh approximation of L1)
    # Behaving like L2 near 0 and L1 away from 0. Differentiable.
    sparsity_loss = np.sum(np.log(np.cosh(alpha * transformed_M))) / alpha
    
    # 4. Orthogonality Constraint (Soft Penalty)
    # Forces A^T @ A to be close to Identity
    I = np.eye(dim)
    ortho_loss = np.linalg.norm(A.T @ A - I, ord='fro')**2
    
    # 5. Total Loss
    total_loss = sparsity_loss + (lambda_ortho * ortho_loss)
    
    return total_loss

# --- Example Usage ---

# 1. Setup Synthetic Data
np.random.seed(67)
N_dim = n_params   # Dimension of the basis (rows of M)
T_samples = 100 # Number of samples (cols of M)

# Create a random coefficient matrix M (dense initially)
# M = np.random.randn(N_dim, T_samples)
M = construct_M(all_linear_pars, n_params=n_params)

# 2. Initialize A
# Start with Identity or a random orthogonal matrix
# A_init = np.eye(N_dim).flatten()
A_init = get_Q_jax((np.random.randn(n_params*n_params)* (2./n_params**2)).reshape(n_params, n_params)).flatten()

# 3. Optimization Configuration
# lambda_ortho: How hard to enforce rotation constraint vs sparsity
# alpha: Higher values make log-cosh closer to true L1 (but harder to optimize)
loss_args = (M, 4.0, 1.5) 

print("Optimizing...")
result = minimize(
    fun=sparse_rotation_loss,
    x0=A_init,
    args=loss_args,
    method='L-BFGS-B',
    options={'disp': True, 'maxiter': 100000}
)

# 4. Extract Results
A_opt = result.x.reshape((N_dim, N_dim))
# A_opt = get_Q_jax(A_opt)
M_sparse = A_opt @ M

print("\nOptimization Success:", result.success)
print(f"Final Loss: {result.fun:.4f}")

# Check Orthogonality (Should be close to Identity)
ortho_check = A_opt.T @ A_opt
print("\nCheck A^T @ A (Diagonal should be ~1.0):")
print(np.round(np.diag(ortho_check), 4))

# Visual check of Sparsity (Kurtosis increases if sparsity increases)
from scipy.stats import kurtosis
kurt_original = np.mean(kurtosis(M, axis=1))
kurt_rotated = np.mean(kurtosis(M_sparse, axis=1))
print(f"\nAvg Kurtosis (Original M): {kurt_original:.2f}")
print(f"Avg Kurtosis (Rotated M):  {kurt_rotated:.2f} (Higher is sparser)")

Aopt = A_opt
# Out:
# Optimizing...
#
# Optimization Success: True
# Final Loss: 7.8151
#
# Check A^T @ A (Diagonal should be ~1.0):
# [0.9432 0.9048 0.8928 0.     0.896  0.8929]
#
# Avg Kurtosis (Original M): 20.76
# Avg Kurtosis (Rotated M):  5.24 (Higher is sparser)

# %%
plt.imshow(Aopt)
plt.colorbar()

# %%
plt.imshow(M)
plt.colorbar()
plt.show()
plt.imshow(M_sparse)
plt.colorbar()
plt.show()

# %%
from scipy.optimize import minimize
import jax.scipy.optimize


np.random.seed(0)

Ainit = (np.random.normal(size=(n_params,n_params))) * (2./n_params**2) # he initialisation

# Ainit = np.random.uniform(size=(n_params,n_params))


# Create loss function
_lossfn = lambda a: lossfn_jac_jax(
    a, all_pars, all_fns, all_linear_pars, all_linear_inds,
    X=X, Fs=Fs, n_params=n_params, delta=0.2, alpha=0.7, smoothl1=False, compare_jacs=False, lambda_flat=1.0
)


res = jax.scipy.optimize.minimize(jax.jit(_lossfn), x0=Ainit.flatten(), 
                                  method="BFGS",
                                  tol=1e-10,
              #options=dict(maxiter=200, disp=True, gtol=1e-3), 
               #jac=True,
                # constraints=constraints,
            #    hess=lambda x: np.zeros_like(x)
               )

Aopt = (res.x.reshape((n_params,n_params)))
Aopt = get_Q_jax(Aopt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 19
#       9 # Ainit = np.random.uniform(size=(n_params,n_params))
#      10
#      11
#      12 # Create loss function
#      13 _lossfn = lambda a: lossfn_jac_jax(
#      14     a, all_pars, all_fns, all_linear_pars, all_linear_inds,
#      15     X=X, Fs=Fs, n_params=n_params, delta=0.2, alpha=0.7, smoothl1=False, compare_jacs=False, lambda_flat=1.0
#      16 )
# ---> 19 res = jax.scipy.optimize.minimize(jax.jit(_lossfn), x0=Ainit.flatten(),
#      20                                   method="BFGS",
#      21                                   tol=1e-10,
#      22               #options=dict(maxiter=200, disp=True, gtol=1e-3),
#      23                #jac=True,
#      24                 # constraints=constraints,
#      25             #    hess=lambda x: np.zeros_like(x)
#      26                )
#      28 Aopt = (res.x.reshape((n_params,n_params)))
#      29 Aopt = get_Q_jax(Aopt)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/scipy/optimize/minimize.py:109, in minimize(fun, x0, args, method, tol, options)
#     106 fun_with_args = lambda x: fun(x, *args)
#     108 if method.lower() == 'bfgs':
# --> 109   results = minimize_bfgs(fun_with_args, x0, **options)
#     110   success = results.converged & jnp.logical_not(results.failed)
#     111   return OptimizeResults(x=results.x_k,
#     112                          success=success,
#     113                          status=results.status,
#    (...)
#     118                          njev=results.ngev,
#     119                          nit=results.k)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/scipy/optimize/bfgs.py:104, in minimize_bfgs(fun, x0, maxiter, norm, gtol, line_search_maxiter)
#     101 d = x0.shape[0]
#     103 initial_H = jnp.eye(d, dtype=x0.dtype)
# --> 104 f_0, g_0 = jax.value_and_grad(fun)(x0)
#     105 state = _BFGSResults(
#     106     converged=jnp.linalg.norm(g_0, ord=norm) < gtol,
#     107     failed=False,
#    (...)
#     118     line_search_status=0,
#     119 )
#     121 def cond_fun(state):
#
#     [... skipping hidden 1 frame]
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/api.py:463, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     461   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     462 if not has_aux:
# --> 463   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     464 else:
#     465   ans, vjp_py, aux = _vjp(
#     466       f_partial, *dyn_args, has_aux=True)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/api.py:1968, in _vjp(fun, has_aux, *primals)
#    1966 if not has_aux:
#    1967   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1968   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    1969   out_tree = out_tree()
#    1970 else:
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:224, in vjp(traceable, primals, has_aux)
#     222 def vjp(traceable, primals, has_aux=False):
#     223   if not has_aux:
# --> 224     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     225   else:
#     226     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:209, in linearize(traceable, *primals, **kwargs)
#     207 _, in_tree = tree_flatten(((primals, primals), {}))
#     208 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 209 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     210 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     211 if any(not out_primal_pval.is_known() for out_primal_pval in out_primals_pvals):
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:575, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     573 fun = trace_to_subjaxpr_nounits(fun, trace, instantiate)
#     574 with core.set_current_trace(trace):
# --> 575   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     576   assert not env
#     577 del trace, fun
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/linear_util.py:187, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     185 def call_wrapped(self, *args, **kwargs):
#     186   """Calls the transformed function"""
# --> 187   return self.f_transformed(*args, **kwargs)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:588, in trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals)
#     581 @lu.transformation2
#     582 def trace_to_subjaxpr_nounits(
#     583     f,
#     584     trace: JaxprTrace,
#     585     instantiate: bool | Sequence[bool],
#     586     in_pvals: Sequence[PartialVal]):
#     587   assert all(isinstance(pv, PartialVal) for pv in in_pvals), in_pvals
# --> 588   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     589       f, trace, instantiate, in_pvals)
#     590   out_pvals = [t.pval for t in out_tracers]
#     591   del out_tracers
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:617, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals)
#     615 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     616 with core.set_current_trace(trace):
# --> 617   ans = f(*in_args)
#     618 assert isinstance(ans, (list, tuple)), (
#     619     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     620 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     621     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/api_util.py:74, in flatten_fun(f, store, in_tree, *args_flat)
#      71 @lu.transformation_with_aux2
#      72 def flatten_fun(f, store, in_tree, *args_flat):
#      73   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 74   ans = f(*py_args, **py_kwargs)
#      75   ans, out_tree = tree_flatten(ans)
#      76   store.store(out_tree)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:78, in jvpfun(f, instantiate, transform_stack, primals, tangents)
#      75 ctx = (source_info_util.transform_name_stack('jvp') if transform_stack
#      76        else contextlib.nullcontext())
#      77 with ctx:
# ---> 78   out_primals, out_tangents = f(tag, primals, tangents)
#      79 if type(instantiate) is bool:
#      80   instantiate = [instantiate] * len(out_tangents)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:113, in jvp_subtrace(f, tag, primals, tangents)
#     110   in_tracers = [maybe_jvp_tracer(trace, x, t)
#     111                 for x, t in zip(primals, tangents)]
#     112   with core.set_current_trace(trace):
# --> 113     ans = f(*in_tracers)
#     114   out = unzip2(map(trace.to_primal_tangent_pair, ans))
#     115 return out
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      87 @lu.transformation_with_aux2
#      88 def flatten_fun_nokwargs(f, store, in_tree, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/api_util.py:294, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     292 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     293 assert next(fixed_args_, sentinel) is sentinel
# --> 294 return _fun(*args, **kwargs)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/scipy/optimize/minimize.py:106, in minimize.<locals>.<lambda>(x)
#     103   msg = "args argument to jax.scipy.optimize.minimize must be a tuple, got {}"
#     104   raise TypeError(msg.format(args))
# --> 106 fun_with_args = lambda x: fun(x, *args)
#     108 if method.lower() == 'bfgs':
#     109   results = minimize_bfgs(fun_with_args, x0, **options)
#
#     [... skipping hidden 1 frame]
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/pjit.py:337, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     332 if config.no_tracing.value:
#     333   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     334                      "`jit`, but 'no_tracing' is set")
#     336 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 337  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     339 maybe_fastpath_data = _get_fastpath_data(
#     340     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     341     jaxpr.consts, jit_info.abstracted_axes,
#     342     pgle_profiler)
#     344 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/pjit.py:197, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     195   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     196 else:
# --> 197   out_flat = pjit_p.bind(*args_flat, **p.params)
#     198   compiled = None
#     199   profiler = None
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/core.py:463, in Primitive.bind(self, *args, **params)
#     461 trace_ctx.set_trace(eval_trace)
#     462 try:
# --> 463   return self.bind_with_trace(prev_trace, args, params)
#     464 finally:
#     465   trace_ctx.set_trace(prev_trace)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/core.py:468, in Primitive.bind_with_trace(self, trace, args, params)
#     467 def bind_with_trace(self, trace, args, params):
# --> 468   return trace.process_primitive(self, args, params)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:397, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     395   raise NotImplementedError(msg)
#     396 with core.set_current_trace(self.parent_trace):
# --> 397   primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     399 if primitive.multiple_results:
#     400   return [maybe_jvp_tracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/pjit.py:2081, in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs)
#    2079 _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    2080 _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 2081 outputs = pjit_p.bind(
#    2082     *primals_in, *_filter_zeros_in(tangents_in),
#    2083     jaxpr=jaxpr_jvp,
#    2084     in_shardings=(*in_shardings, *_filter_zeros_in(in_shardings)),
#    2085     out_shardings=(*out_shardings, *_filter_zeros_out(out_shardings)),
#    2086     in_layouts=(*in_layouts, *_filter_zeros_in(in_layouts)),
#    2087     out_layouts=(*out_layouts, *_filter_zeros_out(out_layouts)),
#    2088     resource_env=resource_env,
#    2089     donated_invars=(*donated_invars, *_filter_zeros_in(donated_invars)),
#    2090     name=name,
#    2091     keep_unused=keep_unused,
#    2092     inline=inline,
#    2093     compiler_options_kvs=compiler_options_kvs)
#    2095 primals_out, tangents_out = split_list(outputs, [len(jaxpr.jaxpr.outvars)])
#    2096 assert len(primals_out) == len(jaxpr.jaxpr.outvars)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/core.py:463, in Primitive.bind(self, *args, **params)
#     461 trace_ctx.set_trace(eval_trace)
#     462 try:
# --> 463   return self.bind_with_trace(prev_trace, args, params)
#     464 finally:
#     465   trace_ctx.set_trace(prev_trace)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/core.py:468, in Primitive.bind_with_trace(self, trace, args, params)
#     467 def bind_with_trace(self, trace, args, params):
# --> 468   return trace.process_primitive(self, args, params)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:213, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     211 if primitive in custom_partial_eval_rules:
#     212   tracers = map(self.to_jaxpr_tracer, tracers)
# --> 213   return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     214 else:
#     215   return self.default_process_primitive(primitive, tracers, params)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/pjit.py:2232, in _pjit_partial_eval(trace, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs, *in_tracers)
#    2230 # Bind known things to pjit_p.
#    2231 known_inputs = [pv.get_known() for pv in in_pvals if pv.is_known()]
# -> 2232 all_known_outs = pjit_p.bind(*known_inputs, **known_params)
#    2233 # Add back in the output fwds.
#    2234 all_known_outs = subs_list(out_fwd, all_known_outs, all_known_outs)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/core.py:463, in Primitive.bind(self, *args, **params)
#     461 trace_ctx.set_trace(eval_trace)
#     462 try:
# --> 463   return self.bind_with_trace(prev_trace, args, params)
#     464 finally:
#     465   trace_ctx.set_trace(prev_trace)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/core.py:468, in Primitive.bind_with_trace(self, trace, args, params)
#     467 def bind_with_trace(self, trace, args, params):
# --> 468   return trace.process_primitive(self, args, params)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/core.py:941, in EvalTrace.process_primitive(self, primitive, args, params)
#     939       return primitive.bind_with_trace(arg._trace, args, params)
#     940 check_eval_args(args)
# --> 941 return primitive.impl(*args, **params)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/pjit.py:1765, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs, *args)
#    1756 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1757 cache_key = pxla.JitGlobalCppCacheKeys(
#    1758     donate_argnums=donated_argnums, donate_argnames=None,
#    1759     device=None, backend=None,
#    (...)
#    1763     out_layouts_treedef=None, out_layouts_leaves=out_layouts,
#    1764     use_resource_env=resource_env is not None)
# -> 1765 return xc._xla.pjit(
#    1766     name, f, call_impl_cache_miss, [], [], cache_key,
#    1767     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1768     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/pjit.py:1741, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1740 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1741   out_flat, compiled, pgle_profiler = _pjit_call_impl_python(
#    1742       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1743       out_shardings=out_shardings, in_layouts=in_layouts,
#    1744       out_layouts=out_layouts, resource_env=resource_env,
#    1745       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1746       inline=inline, compiler_options_kvs=compiler_options_kvs)
#    1747   fastpath_data = _get_fastpath_data(
#    1748       compiled, tree_structure(out_flat), args, out_flat, [], jaxpr.effects,
#    1749       jaxpr.consts, None, pgle_profiler)
#    1750   return out_flat, fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/pjit.py:1663, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs, *args)
#    1660 compiler_options_kvs = compiler_options_kvs + tuple(pgle_compile_options.items())
#    1661 # Passing mutable PGLE profile here since it should be extracted by JAXPR to
#    1662 # initialize the fdo_profile compile option.
# -> 1663 compiled = _resolve_and_lower(
#    1664     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1665     out_shardings=out_shardings, in_layouts=in_layouts,
#    1666     out_layouts=out_layouts, resource_env=resource_env,
#    1667     donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1668     inline=inline, lowering_platforms=None,
#    1669     lowering_parameters=mlir.LoweringParameters(),
#    1670     pgle_profiler=pgle_profiler,
#    1671     compiler_options_kvs=compiler_options_kvs,
#    1672 ).compile()
#    1674 # This check is expensive so only do it if enable_checks is on.
#    1675 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/pjit.py:1630, in _resolve_and_lower(args, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, lowering_platforms, lowering_parameters, pgle_profiler, compiler_options_kvs)
#    1627 in_shardings = _resolve_in_shardings(args, in_shardings)
#    1628 in_layouts = _resolve_in_layouts(args, in_layouts, in_shardings,
#    1629                                  jaxpr.in_avals)
# -> 1630 return _pjit_lower(
#    1631     jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env,
#    1632     donated_invars, name, keep_unused, inline, compiler_options_kvs,
#    1633     lowering_platforms=lowering_platforms,
#    1634     lowering_parameters=lowering_parameters,
#    1635     pgle_profiler=pgle_profiler)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/pjit.py:1795, in _pjit_lower(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs, lowering_platforms, lowering_parameters, pgle_profiler)
#    1792 else:
#    1793   mesh, api_name = ((resource_env.physical_mesh, 'pjit')
#    1794                     if resource_env is not None else (None, 'jit'))
# -> 1795 return pxla.lower_sharding_computation(
#    1796     jaxpr, api_name, name, in_shardings, out_shardings,
#    1797     in_layouts, out_layouts, tuple(donated_invars),
#    1798     keep_unused=keep_unused, context_mesh=mesh,
#    1799     compiler_options_kvs=compiler_options_kvs,
#    1800     lowering_platforms=lowering_platforms,
#    1801     lowering_parameters=lowering_parameters,
#    1802     pgle_profiler=pgle_profiler)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2323, in lower_sharding_computation(closed_jaxpr, api_name, fun_name, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, keep_unused, context_mesh, compiler_options_kvs, lowering_platforms, lowering_parameters, pgle_profiler)
#    2317 semantic_in_shardings = SemanticallyEqualShardings(
#    2318     in_shardings, global_in_avals)  # type: ignore
#    2319 semantic_out_shardings = SemanticallyEqualShardings(
#    2320     out_shardings, global_out_avals)  # type: ignore
#    2322 (module, keepalive, host_callbacks, unordered_effects, ordered_effects,
# -> 2323  nreps, tuple_args, shape_poly_state) = _cached_lowering_to_hlo(
#    2324      closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings,
#    2325      semantic_out_shardings, in_layouts, out_layouts, num_devices,
#    2326      tuple(da_object) if prim_requires_devices else None, donated_invars,
#    2327      name_stack, all_default_mem_kind, inout_aliases,
#    2328      propagated_out_mem_kinds, platforms,
#    2329      lowering_parameters=lowering_parameters,
#    2330      abstract_mesh=abstract_mesh)
#    2332 # backend and device_assignment is passed through to MeshExecutable because
#    2333 # if keep_unused=False and all in_shardings are pruned, then there is no way
#    2334 # to get the device_assignment and backend. So pass it to MeshExecutable
#    2335 # because we calculate the device_assignment and backend before in_shardings,
#    2336 # etc are pruned.
#    2337 return MeshComputation(
#    2338     str(name_stack),
#    2339     module,
#    (...)
#    2369     intermediate_shardings=unique_intermediate_shardings,
#    2370     context_mesh=context_mesh)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1953, in _cached_lowering_to_hlo(closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings, semantic_out_shardings, in_layouts, out_layouts, num_devices, device_assignment, donated_invars, name_stack, all_default_mem_kind, inout_aliases, propagated_out_mem_kinds, platforms, lowering_parameters, abstract_mesh)
#    1949 ordered_effects = list(effects.ordered_effects.filter_in(closed_jaxpr.effects))
#    1950 with dispatch.log_elapsed_time(
#    1951       "Finished jaxpr to MLIR module conversion {fun_name} in {elapsed_time:.9f} sec",
#    1952       fun_name=str(name_stack), event=dispatch.JAXPR_TO_MLIR_MODULE_EVENT):
# -> 1953   lowering_result = mlir.lower_jaxpr_to_module(
#    1954       module_name,
#    1955       closed_jaxpr,
#    1956       ordered_effects=ordered_effects,
#    1957       backend_or_name=backend,
#    1958       platforms=platforms,
#    1959       axis_context=axis_ctx,
#    1960       name_stack=name_stack,
#    1961       donated_args=donated_invars,
#    1962       replicated_args=replicated_args,
#    1963       arg_shardings=in_mlir_shardings,
#    1964       result_shardings=out_mlir_shardings,
#    1965       in_layouts=in_layouts,
#    1966       out_layouts=out_layouts,
#    1967       arg_names=jaxpr.debug_info and jaxpr.debug_info.arg_names,
#    1968       result_names=jaxpr.debug_info and jaxpr.debug_info.result_paths,
#    1969       num_replicas=nreps,
#    1970       num_partitions=num_partitions,
#    1971       all_default_mem_kind=all_default_mem_kind,
#    1972       input_output_aliases=inout_aliases,
#    1973       propagated_out_mem_kinds=propagated_out_mem_kinds,
#    1974       lowering_parameters=lowering_parameters)
#    1975 tuple_args = dispatch.should_tuple_args(len(global_in_avals), backend.platform)
#    1976 unordered_effects = list(
#    1977     effects.ordered_effects.filter_not_in(closed_jaxpr.effects))
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1171, in lower_jaxpr_to_module(***failed resolving arguments***)
#    1169 attrs["mhlo.num_replicas"] = i32_attr(num_replicas)
#    1170 attrs["mhlo.num_partitions"] = i32_attr(num_partitions)
# -> 1171 lower_jaxpr_to_fun(
#    1172     ctx, "main", jaxpr, ordered_effects,
#    1173     name_stack=name_stack,
#    1174     public=True,
#    1175     replicated_args=replicated_args,
#    1176     arg_shardings=arg_shardings,
#    1177     result_shardings=result_shardings,
#    1178     input_output_aliases=input_output_aliases,
#    1179     xla_donated_args=xla_donated_args,
#    1180     arg_names=arg_names,
#    1181     result_names=result_names,
#    1182     arg_memory_kinds=arg_memory_kinds,
#    1183     result_memory_kinds=result_memory_kinds,
#    1184     arg_layouts=in_layouts,
#    1185     result_layouts=out_layouts,
#    1186     propagated_out_mem_kinds=propagated_out_mem_kinds)
#    1187 if config.use_shardy_partitioner.value:
#    1188   pipeline = passmanager.PassManager.parse(
#    1189       'builtin.module(sdy-lift-inlined-meshes)')
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1646, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, public, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts, propagated_out_mem_kinds)
#    1644   callee_name_stack = name_stack
#    1645 consts = [ir_constant(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1646 out_vals, tokens_out = jaxpr_subcomp(
#    1647     ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1648     consts, *args, dim_var_values=dim_var_values)
#    1649 outs: list[IrValues] = []
#    1650 for eff in effects:
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1872, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1869 in_nodes = map(read, eqn.invars)
#    1870 source_info = eqn.source_info.replace(
#    1871     name_stack=name_stack + eqn.source_info.name_stack)
# -> 1872 loc = _source_info_to_location(ctx, eqn.primitive, source_info)
#    1873 with source_info_util.user_context(eqn.source_info.traceback), loc:
#    1874   override_rule = get_override_lowering_rule(eqn.primitive)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:511, in _source_info_to_location(ctx, primitive, source_info)
#     509     loc = ir.Location.unknown()
#     510   else:
# --> 511     loc = _traceback_to_location(ctx, source_info.traceback)
#     512 else:
#     513   frame = source_info_util.user_frame(source_info)
#
# File /usr/local/Caskroom/miniconda/base/envs/pyoperon/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:464, in _traceback_to_location(ctx, tb)
#     462 def _traceback_to_location(ctx: ModuleContext, tb: xc.Traceback) -> ir.Location:
#     463   """Converts a full traceback to a callsite() MLIR location."""
# --> 464   loc = ctx.traceback_caches.traceback_cache.get(tb, None)
#     465   if loc is not None:
#     466     return loc
#
# KeyboardInterrupt:

# %%
Aopt
# Out:
# array([[ 4.48778487e-01, -5.73892714e-02, -4.29659161e-01,
#         -1.17005263e-03,  1.94112403e-01, -6.87233312e-01],
#        [ 2.18107033e-01,  5.38338624e-01, -3.16227703e-01,
#          4.72759283e-04,  7.95225176e-02,  2.02287116e-01],
#        [-4.39422822e-01, -4.19061050e-01, -1.51390175e-01,
#          1.69659527e-03, -3.07998787e-01, -3.21183541e-01],
#        [ 6.12816147e-01, -7.31681963e-02,  4.34500326e-01,
#         -2.44085725e-03, -5.56582224e-01, -7.13137849e-02],
#        [-3.48693865e-01,  6.38660821e-01,  3.13610766e-01,
#          5.03187700e-03, -1.44513785e-01, -4.98481626e-01],
#        [-6.32791317e-02,  1.51037421e-01, -5.46056044e-01,
#         -1.49788436e-03, -6.53051577e-01,  1.51399235e-01]])

# %%
Aopt @ Aopt.T
# Out:
# array([[ 0.89927327,  0.07927432,  0.05283193,  0.03350328, -0.01336895,
#         -0.03325852],
#        [ 0.07927432,  0.48462324, -0.36302752, -0.10181863,  0.05626466,
#          0.2188788 ],
#        [ 0.05283193, -0.36302752,  0.58964856, -0.11007522,  0.04273128,
#          0.19968952],
#        [ 0.03350328, -0.10181863, -0.11007522,  0.88456313, -0.00818078,
#          0.06559256],
#        [-0.01336895,  0.05626466,  0.04273128, -0.00818078,  0.89722025,
#         -0.03382465],
#        [-0.03325852,  0.2188788 ,  0.19968952,  0.06559256, -0.03382465,
#          0.77439409]])

# %%
plt.imshow(get_Q_jax(Ainit))
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 plt.imshow(get_Q_jax(Ainit))
#       2 plt.colorbar()
#
# NameError: name 'Ainit' is not defined

# %%
plt.imshow((Aopt))
plt.colorbar()

# %%
_lossfn = lambda a: lossfn_jac_jax(a, all_pars, all_fns, all_linear_pars, all_linear_inds, parts=True, X=X, Fs=Fs, n_params=n_params)

_lossfn(Aopt), _lossfn(np.eye(n_params))
# Out:
# ((Array(19.652515, dtype=float32),
#   Array(0.01351071, dtype=float32),
#   Array(193.93889, dtype=float32)),
#  (Array(11.926368, dtype=float32),
#   Array(0.05573259, dtype=float32),
#   Array(224.83926, dtype=float32)))

# %%
all_linear_pars, mdl_coords
# Out:
# ([array([ 0.198915,  0.740551, -0.254262,  0.231963, -0.131264]),
#   array([-5.00000e-06,  9.99998e-01,  1.46357e-01,  2.97831e-01,
#          -1.13143e-01,  3.35804e-01, -1.77085e-01]),
#   array([-0.04382 ,  1.062336,  0.385171, -0.113036, -0.101597]),
#   array([-0.070241,  1.024071,  6.283185,  0.040789, -0.888934]),
#   array([ 0.      ,  1.000001,  0.30316 , -0.296884,  0.174063,  0.113381,
#           0.132586]),
#   array([-4.00000e-06,  9.99999e-01,  1.33432e-01,  2.26473e-01,
#           1.68353e-01, -2.66463e-01,  2.62993e-01])],
#  ['(0.198915 + (0.740551 * (((sqrt((0.997869 * X4)) + ((-0.254262) * X5)) + (0.231963 * X2)) + ((-0.131264) * X6))))',
#   '((-0.000005) + (0.999998 * ((((0.146357 * X2) + (0.297831 * X3)) + ((-0.113143) * X6)) + (0.335804 + ((-0.177085) * X1)))))',
#   '((-0.043820) + (1.062336 * ((0.385171 + ((0.001209 * X3) ^ (0.474258 * X4))) + (((-0.113036) * X5) + ((-0.101597) * X6)))))',
#   '((-0.070241) + (1.024071 * ((sqrt((5.114736 * X4)) + ((6.283185 * X3) * (0.040789 * X1))) + ((-0.888934) * X4))))',
#   '(0.000000 + (1.000001 * (((0.303160 + ((-0.296884) * X4)) + (0.174063 * X2)) + ((0.113381 * X1) + (0.132586 * X5)))))',
#   '((-0.000004) + (0.999999 * (((((0.133432 * X3) + (0.226473 * X6)) + (0.168353 * X2)) + ((-0.266463) * X4)) + 0.262993)))'])

# %%
plt.imshow((Aopt @ construct_M(all_linear_pars, n_params=n_params)))
plt.colorbar()

# %%
plt.imshow(construct_M(all_linear_pars, n_params=n_params))
plt.colorbar()

# %%
get_pruned_expressions(np.eye(n_params), 
                      all_param_dicts,
                       all_pars, all_linear_pars, all_expr, all_linear_labels, remove_floats=False, threshold=1e-20, n_params=n_params
                       )
# Out:
# (['0.172*X2 + 0.74*X4**0.5 - 0.188*X5 - 0.097*X6 + 0.199',
#   '-0.177*X1 + 0.146*X2 + 0.298*X3 - 0.113*X6 + 0.336',
#   '-0.12*X5 - 0.108*X6 + 1.062*(0.001*X3)**(0.474*X4) + 0.365',
#   '0.262*X1*X3 + 2.316*X4**0.5 - 0.91*X4 - 0.07',
#   '0.113*X1 + 0.174*X2 - 0.297*X4 + 0.133*X5 + 0.303',
#   '0.168*X2 + 0.133*X3 - 0.266*X4 + 0.226*X6 + 0.263'],
#  [[0.172, 0.74, 0.5, 0.188, 0.097, 0.199],
#   [-0.177, 0.146, 0.298, 0.113, 0.336],
#   [-0.12, 0.108, 1.062, 0.001, 0.474, 0.365],
#   [0.262, 2.316, 0.5, 0.91, 0.07],
#   [0.113, 0.174, 0.297, 0.133, 0.303],
#   [0.168, 0.133, 0.266, 0.226, 0.263]])

# %%
sr_exprs_vanilla, _ = get_pruned_expressions_final(np.eye(n_params), 
                      all_param_dicts,
                       all_pars, all_linear_pars, 
                       all_expr, all_linear_labels, 
                       remove_floats=False, threshold=0.05, n_params=n_params, X=X_test, Fs=Fs_test
                       )
# Out:
# Looking at component 0
#   delta: 0.000000
#   zeroed component -> skip!
#   delta: 0.754252
#   delta: 0.682634
#   delta: 0.067816
# Looking at component 1
#   delta: 0.000000
#   zeroed component -> skip!
#   delta: 0.032069
#   delta: 1.356299
#   delta: 0.120147
#   delta: 0.032069
#   delta: 3.670030
# Looking at component 2
#   delta: 0.000000
#   zeroed component -> skip!
#   delta: 0.032069
#   delta: 0.884682
#   delta: 0.043384
# Looking at component 3
#   delta: 0.000000
#   zeroed component -> skip!
#   delta: 5.656615
#   delta: 5.656615
#   delta: 0.309405
# Looking at component 4
#   delta: 0.000000
#   zeroed component -> skip!
#   delta: 0.043384
#   delta: 0.142453
#   delta: 0.239899
#   delta: 0.489822
#   delta: 0.214685
# Looking at component 5
#   delta: 0.000000
#   zeroed component -> skip!
#   delta: 0.067931
#   delta: 4.678417
#   delta: 0.330170
#   delta: -0.009808
#   delta: -0.009808

# %%
sr_exprs_vanilla
# Out:
# ['0.172*X2 + 0.74*X4**0.5 - 0.188*X5 - 0.097*X6',
#  '-0.177*X1 + 0.298*X3 - 0.113*X6',
#  '-0.12*X5 + 1.062*(0.001*X3)**(0.474*X4)',
#  '0.262*X1*X3 + 2.316*X4**0.5 - 0.91*X4',
#  '0.113*X1 + 0.174*X2 - 0.297*X4 + 0.133*X5',
#  '0.168*X2 + 0.133*X3 + 0.226*X6']

# %%
sr_exprs_vanilla
# Out:
# ['0.172*X2 + 0.74*X4**0.5 - 0.188*X5 - 0.097*X6',
#  '-0.177*X1 + 0.298*X3 - 0.113*X6',
#  '-0.12*X5 + 1.062*(0.001*X3)**(0.474*X4)',
#  '0.262*X1*X3 + 2.316*X4**0.5 - 0.91*X4',
#  '0.113*X1 + 0.174*X2 - 0.297*X4 + 0.133*X5',
#  '0.168*X2 + 0.133*X3 + 0.226*X6']

# %%
fit_exprs0, _ = get_pruned_expressions(Aopt, all_param_dicts,
            all_pars, all_linear_pars, all_expr, all_linear_labels, remove_floats=False, threshold=0.1, decimal=3, n_params=n_params)

# %%
fit_exprs0
# Out:
# ['0.114*X2 + 0.332*X4**0.5 - 0.126*X4 - 0.038*X5 + 0.107*X6 - 0.456*(0.001*X3)**(0.474*X4) + 0.2',
#  '0.086*X3 + 0.161*X4**0.5 - 0.336*(0.001*X3)**(0.474*X4) + 0.138',
#  '0.033*X2 + 0.052*X3 - 0.325*X4**0.5 - 0.036*X5 - 0.161*(0.001*X3)**(0.474*X4) + 0.059',
#  '0.065*X2 + 0.453*X4**0.5 - 0.092*X4 - 0.071*X5 + 0.462*(0.001*X3)**(0.474*X4) + 0.293',
#  '-0.072*X1 + 0.121*X3 - 0.258*X4**0.5 - 0.066*X4 + 0.056*X6 + 0.333*(0.001*X3)**(0.474*X4) + 0.243',
#  '0.074*X2 - 0.127*X4 - 0.58*(0.001*X3)**(0.474*X4) + 0.251']

# %%
fit_exprs, _ = get_pruned_expressions_final(Aopt, all_param_dicts,
            all_pars, all_linear_pars, all_expr, all_linear_labels,
             remove_floats=False, threshold=0.05, n_params=n_params, X=X_test, Fs=Fs_test, decimal=2, update=False, verbose=True)
# Out:
# Looking at component 0
#   delta: 0.000000
#   delta: 526.271423
#   delta: 14426.607422
#   delta: 1.764017
#   delta: -0.007055
# Looking at component 1
#   delta: 0.000000
#   delta: 278.650879
#   delta: 0.496303
#   delta: 0.154283
#   delta: -0.058235
#   delta: -0.058235
#   delta: 12.457477
# Looking at component 2
#   delta: 0.000000
#   delta: 3276574.000000
#   delta: -0.058235
#   delta: 0.453571
#   delta: 0.037727
# Looking at component 3
#   delta: 0.000000
#   delta: 0.035805
#   delta: 0.035805
#   delta: 0.035805
#   delta: 0.035805
# Looking at component 4
#   delta: 0.000000
#   delta: 1.100600
#   delta: 0.035805
#   delta: 0.029592
#   delta: 0.099106
#   delta: 1.309636
#   delta: 0.067360
# Looking at component 5
#   delta: 0.000000
#   delta: -0.264550
#   delta: -0.264550
#   delta: -0.264550
#   delta: -0.264550
#   delta: -0.264550
#   delta: -0.264550

# %%
fit_exprs
# Out:
# ['-0.46*0**X4 + 0.04*X2 + 0.33*X4**0.5 - 0.06*X5',
#  '-0.34*0**X4 - 0.05*X1 + 0.05*X2 + 0.09*X3 + 0.16*X4**0.5 - 0.02*X5',
#  '-0.16*0**X4 - 0.02*X1 + 0.08*X2 + 0.05*X3 - 0.33*X4**0.5 - 0.03*X5',
#  '0.46*0**X4 + 0.03*X1 + 0.12*X2 + 0.45*X4**0.5 - 0.05*X5',
#  '0.33*0**X4 - 0.07*X1 + 0.08*X2 + 0.12*X3 - 0.26*X4**0.5 - 0.03*X5',
#  '-0.58*0**X4 + 0.04*X1 + 0.08*X2 + 0.01*X3 - 0.05*X4**0.5 + 0.02*X5']

# %%
check_flats = lambda c: check_flattening(c, X=X, Fs=Fs)

# %%
n_d = 1
mdl_flats, mdl_J = check_flats(mdl_coords)
frob_flats, frob_J = check_flats(frob_coords)

# %%
from copy import deepcopy
fit_exprs2 = deepcopy(fit_exprs)

# substitute in mdl coordinates for zero components
# fit_exprs2[1] ="0.0" 
# fit_exprs2[0] = "0.0"

fit_exprs2, mdl_coords
# Out:
# (['-0.46*0**X4 + 0.04*X2 + 0.33*X4**0.5 - 0.06*X5',
#   '-0.34*0**X4 - 0.05*X1 + 0.05*X2 + 0.09*X3 + 0.16*X4**0.5 - 0.02*X5',
#   '-0.16*0**X4 - 0.02*X1 + 0.08*X2 + 0.05*X3 - 0.33*X4**0.5 - 0.03*X5',
#   '0.46*0**X4 + 0.03*X1 + 0.12*X2 + 0.45*X4**0.5 - 0.05*X5',
#   '0.33*0**X4 - 0.07*X1 + 0.08*X2 + 0.12*X3 - 0.26*X4**0.5 - 0.03*X5',
#   '-0.58*0**X4 + 0.04*X1 + 0.08*X2 + 0.01*X3 - 0.05*X4**0.5 + 0.02*X5'],
#  ['(0.198915 + (0.740551 * (((sqrt((0.997869 * X4)) + ((-0.254262) * X5)) + (0.231963 * X2)) + ((-0.131264) * X6))))',
#   '((-0.000005) + (0.999998 * ((((0.146357 * X2) + (0.297831 * X3)) + ((-0.113143) * X6)) + (0.335804 + ((-0.177085) * X1)))))',
#   '((-0.043820) + (1.062336 * ((0.385171 + ((0.001209 * X3) ^ (0.474258 * X4))) + (((-0.113036) * X5) + ((-0.101597) * X6)))))',
#   '((-0.070241) + (1.024071 * ((sqrt((5.114736 * X4)) + ((6.283185 * X3) * (0.040789 * X1))) + ((-0.888934) * X4))))',
#   '(0.000000 + (1.000001 * (((0.303160 + ((-0.296884) * X4)) + (0.174063 * X2)) + ((0.113381 * X1) + (0.132586 * X5)))))',
#   '((-0.000004) + (0.999999 * (((((0.133432 * X3) + (0.226473 * X6)) + (0.168353 * X2)) + ((-0.266463) * X4)) + 0.262993)))'])

# %%
n_params
# Out:
# 6

# %%
n_d = 1
fit_expr_flats0, _ = check_flats(fit_exprs0)
sr_expr_flats, _ = check_flats(sr_exprs_vanilla)

fit_expr_flats, _ = check_flattening(fit_exprs, X=X, Fs=Fs)

# %%
plt.imshow(Fs.mean(0))
plt.colorbar()

# %%
sr_exprs_vanilla
# Out:
# ['0.172*X2 + 0.74*X4**0.5 - 0.188*X5 - 0.097*X6',
#  '-0.177*X1 + 0.298*X3 - 0.113*X6',
#  '-0.12*X5 + 1.062*(0.001*X3)**(0.474*X4)',
#  '0.262*X1*X3 + 2.316*X4**0.5 - 0.91*X4',
#  '0.113*X1 + 0.174*X2 - 0.297*X4 + 0.133*X5',
#  '0.168*X2 + 0.133*X3 + 0.226*X6']

# %%
from sr_utils import norm

# %%
jax.vmap(norm)(sr_expr_flats - jnp.eye(n_params)).mean()
# Out:
# Array(10.782819, dtype=float32)

# %%
jax.vmap(norm)(fit_expr_flats0 - jnp.eye(n_params)).mean()
# Out:
# Array(398750., dtype=float32)

# %%
jax.vmap(norm)(fit_expr_flats - jnp.eye(n_params)).mean()
# Out:
# Array(8412.452, dtype=float32)

# %%
jax.vmap(norm)(mdl_flats - jnp.eye(n_params)).mean()
# Out:
# Array(10.49717, dtype=float32)

# %%
jax.vmap(norm)(sr_expr_flats - jnp.eye(n_params)).mean()
# Out:
# Array(10.782819, dtype=float32)

# %%
plt.imshow(mdl_flats.mean(0))
plt.colorbar()

# %%
mdl_flats = jax.vmap(flatten_with_numerical_jacobian)(mdl_J, Fs)
frob_flats = jax.vmap(flatten_with_numerical_jacobian)(frob_J, Fs)

# %%
mdl_flats.mean(0), frob_flats.mean(0)
# Out:
# (Array([[ 2.4563215 , -1.0552682 , -1.6116586 , -2.198395  ,  0.31886175,
#          -0.45933005],
#         [-1.0552682 ,  2.8924005 ,  0.0187435 ,  0.9797838 , -0.3962306 ,
#           0.4948252 ],
#         [-1.6116586 ,  0.01874351,  4.3202133 ,  2.7871516 , -0.3198155 ,
#           0.9111278 ],
#         [-2.198395  ,  0.9797837 ,  2.7871516 ,  4.6589937 , -0.5573241 ,
#           0.84254825],
#         [ 0.31886175, -0.3962306 , -0.3198155 , -0.5573241 ,  1.9079554 ,
#          -0.97712374],
#         [-0.45933005,  0.4948252 ,  0.9111278 ,  0.84254825, -0.97712374,
#           1.9275173 ]], dtype=float32),
#  Array([[ 2.8447805e+01,  2.0813373e-01, -8.6300301e+01, -3.1287025e+01,
#          -3.8451397e+01,  1.2385985e+01],
#         [ 2.0813373e-01,  9.5604038e+00, -5.0367942e+00, -6.4598179e+00,
#          -8.5565939e+00,  1.4313170e-01],
#         [-8.6300301e+01, -5.0367942e+00,  2.7821011e+02,  1.0166744e+02,
#           1.2678721e+02, -3.9813797e+01],
#         [-3.1287025e+01, -6.4598179e+00,  1.0166744e+02,  7.7711853e+01,
#           4.9840618e+01, -1.5486795e+01],
#         [-3.8451393e+01, -8.5565939e+00,  1.2678721e+02,  4.9840618e+01,
#           6.4715752e+01, -1.8777637e+01],
#         [ 1.2385985e+01,  1.4313172e-01, -3.9813797e+01, -1.5486795e+01,
#          -1.8777637e+01,  7.4032779e+00]], dtype=float32))

# %%
#@title fisher code
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

def plot_fisher_ellipse(fisher_matrix, mean=None, ax=None, color='blue', 
                        alpha=1.0, linestyle='-',
                       label=""):
    """
    Plots a Fisher information matrix ellipse.

    Parameters:
        fisher_matrix (numpy.ndarray): Fisher information matrix.
        mean (numpy.ndarray, optional): Mean vector. Defaults to None, in which case the ellipse will be centered at (0, 0).
        ax (matplotlib.axes.Axes, optional): Axes to plot on. If not provided, a new figure will be created.
        color (str, optional): Color of the ellipse. Defaults to 'blue'.
        alpha (float, optional): Transparency of the ellipse. Defaults to 0.5.
        linestyle (str, optional): Linestyle of the ellipse. Defaults to '-'.

    Returns:
        matplotlib.axes.Axes: Axes object with the ellipse plotted.
    """
    if ax is None:
        _, ax = plt.subplots()

    # Invert the Fisher information matrix to get the covariance matrix
    covariance_matrix = np.linalg.inv(fisher_matrix)

    # Calculate eigenvalues and eigenvectors of the covariance matrix
    eigenvalues, eigenvectors = np.linalg.eigh(covariance_matrix)
    order = eigenvalues.argsort()[::-1]
    eigenvalues = eigenvalues[order]
    eigenvectors = eigenvectors[:, order]

    # Calculate ellipse angle
    angle = np.degrees(np.arctan2(*eigenvectors[:, 0][::-1]))

    # If mean is provided, set the center of the ellipse accordingly
    if mean is not None:
        center = mean
    else:
        center = np.zeros_like(covariance_matrix.shape[0])

    # Create ellipse for 1-sigma contour
    ellipse = Ellipse(xy=center,
                      width=2 * np.sqrt(eigenvalues[0]),
                      height=2 * np.sqrt(eigenvalues[1]),
                      angle=angle,
                      edgecolor=color,
                      linestyle=linestyle,
                      facecolor='none',
                      alpha=alpha,
                      label=label)

    # Create ellipse for 2-sigma contour
    ellipse2 = Ellipse(xy=center,
                       width=2 * 2 * np.sqrt(eigenvalues[0]),
                       height=2 * 2 * np.sqrt(eigenvalues[1]),
                       angle=angle,
                       edgecolor=color,
                       linestyle=linestyle,
                       facecolor='none',
                       alpha=alpha)

    ax.add_patch(ellipse)
    ax.add_patch(ellipse2)
    #ax.set_aspect('equal', 'box')
    ax.autoscale()
    return ax

# %%
#nn_flats = jax.vmap(jax.vmap(flatten_with_numerical_jacobian))(dys, ensemble_Fs).mean(0)

nn_flats = jax.vmap(flatten_with_numerical_jacobian)(dy, Fs)

# %%
Fs, dy
# Out:
# (array([[[ 1.79591939e-01, -7.33189583e-02, -1.24796897e-01,
#           -7.79308053e-03, -5.81283635e-03,  1.16888471e-02],
#          [-7.33189583e-02,  1.45286441e-01,  6.55122995e-02,
#           -1.37311826e-02, -1.28430761e-02,  7.17298267e-03],
#          [-1.24796897e-01,  6.55122995e-02,  1.49071470e-01,
#            2.48202519e-03,  3.14184627e-03, -7.76583143e-03],
#          [-7.79308053e-03, -1.37311826e-02,  2.48202519e-03,
#            3.20214450e-01,  9.45476722e-03, -2.39792410e-02],
#          [-5.81283635e-03, -1.28430761e-02,  3.14184627e-03,
#            9.45476722e-03,  1.07455745e-01,  4.82877204e-03],
#          [ 1.16888471e-02,  7.17298267e-03, -7.76583143e-03,
#           -2.39792410e-02,  4.82877204e-03,  1.24740891e-01]],
#
#         [[ 1.81986883e-01, -7.73589462e-02, -1.45884797e-01,
#           -4.36851718e-02, -1.15073016e-02,  8.85508768e-03],
#          [-7.73589462e-02,  1.38309687e-01,  7.04474673e-02,
#            2.69424673e-02, -3.46858567e-03, -4.63654753e-03],
#          [-1.45884797e-01,  7.04474673e-02,  1.92029357e-01,
#            2.77283676e-02,  7.00355042e-03, -7.79095292e-03],
#          [-4.36851718e-02,  2.69424673e-02,  2.77283676e-02,
#            9.92293739e+00, -1.66127216e-02, -1.57446191e-02],
#          [-1.15073016e-02, -3.46858567e-03,  7.00355042e-03,
#           -1.66127216e-02,  1.06382467e-01, -1.30437932e-03],
#          [ 8.85508768e-03, -4.63654753e-03, -7.79095292e-03,
#           -1.57446191e-02, -1.30437932e-03,  1.03843600e-01]],
#
#         [[ 1.81336969e-01, -7.78784156e-02, -7.80940354e-02,
#           -2.92331306e-03,  3.43362248e-04,  3.00564733e-03],
#          [-7.78784156e-02,  1.60305128e-01,  4.40422818e-02,
#           -1.46451581e-03, -1.12232063e-02, -1.05876159e-02],
evalues_frob = jax.vmap(get_evalues)(frob_flats)

evalues_fitexpr = jax.vmap(get_evalues)(sr_expr_flats)

# %%
evalues_fitexpr
# Out:
# Array([[ 0.6571935 ,  0.7232051 ,  1.0049204 ,  2.1425016 ,  3.3519228 ,
#          9.638329  ],
#        [ 0.63709116,  0.80284953,  1.3216833 ,  1.9427859 ,  2.4971802 ,
#          8.73869   ],
#        [ 0.51114404,  0.6022346 ,  0.7814536 ,  2.376276  ,  3.0100012 ,
#          8.300582  ],
#        ...,
#        [ 0.65956026,  0.8116022 ,  2.09662   ,  3.7622583 ,  6.1766744 ,
#         12.629536  ],
#        [ 0.43177804,  0.8031032 ,  0.99618024,  1.8135083 ,  2.6262283 ,
#          6.8099165 ],
#        [ 0.45314252,  0.84253377,  0.97342503,  1.2648287 ,  2.1376836 ,
#          4.695568  ]], dtype=float32)

# %%
plt.subplot(121)
plt.title("eigenvalue 1")

plt.hist(evalues_nn[:, 3], label="NN")
plt.hist(evalues_mdl[:, 3], alpha=0.4, label="SR mdl")
plt.hist(evalues_frob[:, 3], alpha=0.2, label="SR frob")
plt.hist(evalues_fitexpr[:, 3], alpha=0.2, label="fit expr")


plt.subplot(122)
plt.title("eigenvalue 2")
plt.hist(evalues_nn[:, 1], label="NN")
plt.hist(evalues_mdl[:, 1], alpha=0.4, label="SR mdl")
plt.hist(evalues_frob[:, 1], alpha=0.2, label="SR frob")
plt.hist(evalues_fitexpr[:, 1], alpha=0.2, label="fit expr")


plt.legend(framealpha=0.0)

# %%
bins = np.linspace(0, 10, 20)
plt.hist(np.array(evalues_nn).flatten(), bins=bins, label='NN')
plt.hist(np.array(evalues_frob).flatten(), bins=bins, alpha=0.3, label='SR frob')
plt.hist(np.array(evalues_mdl).flatten(), bins=bins, alpha=0.3, label='SR MDL')
plt.hist(np.array(evalues_fitexpr).flatten(), bins=bins, alpha=0.3, label='SR postprocess')
plt.legend(framealpha=0.0)

# %%
import corner

cols = ['eigenvalue %d'%(i) for i in range(n_params)]

figure = corner.corner(np.array(evalues_nn), color="blue", labels=cols, hist_kwargs=dict(label="NN"))
figure = corner.corner(np.array(evalues_mdl), color="orange", fig=figure, labels=cols, alpha=0.2, hist_kwargs=dict(label="SR mdl"))
figure = corner.corner(np.array(evalues_frob), color="green", fig=figure, labels=cols, alpha=0.2, hist_kwargs=dict(label="SR frob"))
figure = corner.corner(np.array(evalues_fitexpr), color="pink", fig=figure, labels=cols, alpha=0.2, hist_kwargs=dict(label="SR postprocess"))


plt.legend(framealpha=0.0)

# %%
nn_flats
# Out:
# Array([[[ 1.00980687e+00,  1.75279081e-02,  1.63147628e-01,
#           6.49733990e-02,  4.43253219e-02,  9.18522179e-02],
#         [ 1.75278634e-02,  9.21499968e-01, -5.11294156e-02,
#           2.34855413e-02,  3.46540734e-02, -2.82507986e-02],
#         [ 1.63147673e-01, -5.11293113e-02,  1.08728909e+00,
#          -1.27761096e-01, -3.14921737e-02, -1.50711015e-01],
#           6.94270134e-02,  7.47628659e-02,  2.30390728e-02],
#         [ 7.43271038e-02, -1.97112277e-01,  1.02324438e+00,
#           3.48381698e-02, -1.25723481e-02, -6.03603572e-03],
#         [ 1.01860762e-02,  6.94270134e-02,  3.48381698e-02,
#           9.96653199e-01, -1.74560606e-01,  1.18271172e-01],
#         [-4.10061181e-02,  7.47629032e-02, -1.25723034e-02,
#          -1.74560606e-01,  1.16547072e+00,  3.09136510e-03],
#         [ 3.54384482e-02,  2.30391026e-02, -6.03606552e-03,
#           1.18271157e-01,  3.09139490e-03,  1.11970580e+00]],
#
#        [[ 8.29639077e-01,  4.16386724e-02, -4.55137715e-02,
#           3.45480144e-02,  6.31370991e-02,  1.08008236e-02],
#         [ 4.16386575e-02,  1.01886988e+00,  2.01306269e-02,
#          -2.77290642e-02, -1.24478564e-02,  2.55172551e-02],
#         [-4.55137528e-02,  2.01306939e-02,  1.17369187e+00,
#          -2.89807856e-01, -1.31291211e-01, -9.62589085e-02],
#         [ 3.45480144e-02, -2.77289674e-02, -2.89807767e-01,
#           1.18151498e+00,  8.94438922e-02,  6.21230304e-02],
#         [ 6.31371737e-02, -1.24478191e-02, -1.31291181e-01,
#           8.94439071e-02,  9.87696350e-01,  6.13997728e-02],
#         [ 1.08008385e-02,  2.55172551e-02, -9.62589160e-02,
#           6.21229857e-02,  6.13997653e-02,  9.66954708e-01]]],      dtype=float32)

# %%
nn_flats[:, [0,1],].shape
# Out:
# (4000, 2, 6)

# %%
# plot a smattering of fishers

randidx = np.random.choice(500, size=(12), replace=False)


_, axs = plt.subplots(1, 2, sharey=True) 


comps_to_plot = [0,3]

ax = axs[0]

for i,r in enumerate(randidx):
    if i == 0:
        ax = plot_fisher_ellipse(nn_flats[:, comps_to_plot, :][:, :, comps_to_plot][r],ax=ax, mean=X_test[r], color=cm(3), linestyle='--')

    else: 
        if i == len(randidx) - 1:
            labels = ["MDL", "score"]
        else:
            labels = [None, None]
            
        plot_fisher_ellipse(nn_flats[:, comps_to_plot, :][:, :, comps_to_plot][r], mean=X_test[:, comps_to_plot][r], ax=ax, label=labels[0], linestyle='--', color=cm(3))
        #plot_fisher_ellipse(score_flats[r], mean=X[r], ax=ax, label=labels[1], linestyle=':', color=cm(2))



ax.set_ylabel(r"$\mu_2$")
ax.set_xlabel(r"$\mu_1$")
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
ax.set_title("NN flats")
ax.set_box_aspect(1)
ax = axs[1]

mdl_evalues = []

for i,r in enumerate(randidx):
    if i == 0:
        ax = plot_fisher_ellipse(mdl_flats[:, comps_to_plot, :][:, :, comps_to_plot][r],ax=ax, mean=X_test[:, comps_to_plot][r], color=cm(3), linestyle='--')

    else: 
        if i == len(randidx) - 1:
            labels = ["MDL", "frob"]
        else:
            labels = [None, None]
        
        plot_fisher_ellipse(mdl_flats[:, comps_to_plot, :][:, :, comps_to_plot][r], mean=X_test[r], ax=ax, label=labels[0], linestyle='--', color=cm(3))


for i,r in enumerate(randidx):
    if i == 0:
        ax = plot_fisher_ellipse(frob_flats[:, comps_to_plot, :][:, :, comps_to_plot][r],ax=ax, mean=X_test[:, comps_to_plot][r], color=cm(3), linestyle='--')

    else: 
        if i == len(randidx) - 1:
            labels = ["MDL", "frob"]
        else:
            labels = [None, None]
        
        plot_fisher_ellipse(frob_flats[:, comps_to_plot, :][:, :, comps_to_plot][r], mean=X_test[:, comps_to_plot][r], ax=ax, label=labels[1], linestyle=':', color=cm(4))



ax.set_ylabel(r"$\mu_2$")
ax.set_xlabel(r"$\mu_1$")
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
ax.set_title("SR flats")

ax.set_box_aspect(1)


plt.legend()

#plt.tight_layout()

# %%
# plot a smattering of fishers

randidx = np.random.choice(500, size=(12), replace=False)


comps_to_plot = [2,4]


_, axs = plt.subplots(1, 3, sharey=True)


ax = axs[0]

for i,r in enumerate(randidx):
    if i == 0:
        ax = plot_fisher_ellipse(nn_flats[:, comps_to_plot, :][:, :, comps_to_plot][r],ax=ax, mean=X[:, comps_to_plot][r], color=cm(3), linestyle='--')

    else: 
        if i == len(randidx) - 1:
            labels = ["MDL", "score"]
        else:
            labels = [None, None]
            
        plot_fisher_ellipse(nn_flats[:, comps_to_plot, :][:, :, comps_to_plot][r], mean=X_test[:, comps_to_plot][r], ax=ax, label=labels[0], linestyle='--', color=cm(3))
        #plot_fisher_ellipse(score_flats[r], mean=X[r], ax=ax, label=labels[1], linestyle=':', color=cm(2))



ax.set_ylabel(r"$\theta_2$")
ax.set_xlabel(r"$\theta_1$")
ax.set_xlim(-4, 4)
ax.set_ylim(-4, 4)
ax.set_title("NN flats")
ax.set_box_aspect(1)
ax = axs[1]

mdl_evalues = []

for i,r in enumerate(randidx):
    if i == 0:
        ax = plot_fisher_ellipse(mdl_flats[:, comps_to_plot, :][:, :, comps_to_plot][r],ax=ax, mean=X_test[:, comps_to_plot][r], color=cm(3), linestyle='--')

    else: 
        if i == len(randidx) - 1:
            labels = ["MDL", "frob"]
        else:
            labels = [None, None]
        
        plot_fisher_ellipse(mdl_flats[:, comps_to_plot, :][:, :, comps_to_plot][r], mean=X_test[:, comps_to_plot][r], ax=ax, label=labels[0], linestyle='--', color=cm(3))


for i,r in enumerate(randidx):
    if i == 0:
        ax = plot_fisher_ellipse(frob_flats[:, comps_to_plot, :][:, :, comps_to_plot][r],ax=ax, mean=X_test[:, comps_to_plot][r], color=cm(3), linestyle='--')

    else: 
        if i == len(randidx) - 1:
            labels = ["MDL", "frob"]
        else:
            labels = [None, None]
        
        plot_fisher_ellipse(frob_flats[:, comps_to_plot, :][:, :, comps_to_plot][r], mean=X[:, comps_to_plot][r], ax=ax, label=labels[1], linestyle=':', color=cm(4))

ax.legend()

ax.set_ylabel(r"$\theta_2$")
ax.set_xlabel(r"$\theta_1$")
ax.set_xlim(-4, 4)
ax.set_ylim(-4, 4)
ax.set_title("SR flats")


ax.set_box_aspect(1)




ax = axs[2]

for i,r in enumerate(randidx):
    if i == 0:
        ax = plot_fisher_ellipse(Fs_test[:, comps_to_plot, :][:, :, comps_to_plot][r]*50,ax=ax, mean=X_test[:, comps_to_plot][r], color='k', linestyle=':')

    else: 
        if i == len(randidx) - 1:
            labels = ["MDL", "frob"]
        else:
            labels = [None, None]
            
        plot_fisher_ellipse(Fs_test[:, comps_to_plot, :][:, :, comps_to_plot][r] / 10., mean=X_test[:, comps_to_plot][r], ax=ax, label=labels[1], linestyle=':', color='k')
        #plot_fisher_ellipse(score_flats[r], mean=X[r], ax=ax, label=labels[1], linestyle=':', color=cm(2))




ax.set_ylabel(r"$\theta_2$")
ax.set_xlabel(r"$\theta_1$")
ax.set_xlim(-4, 4)
ax.set_ylim(-4, 4)
ax.set_title("Unflattened Fisher")
ax.set_box_aspect(1)



#plt.tight_layout()

# %%
# plot a smattering of fishers

randidx = np.random.choice(1000, size=(10), replace=False)


for i,r in enumerate(randidx):
    if i == 0:
        ax = plot_fisher_ellipse(mdl_flats[:, comps_to_plot, :][:, :, comps_to_plot][r], mean=np.array([0, 0]), color=cm(3))

    else: 
        if i == len(randidx) - 1:
            labels = ["MDL", "score"]
        else:
            labels = [None, None]
            
        plot_fisher_ellipse(mdl_flats[:, comps_to_plot, :][:, :, comps_to_plot][r], mean=np.array([0, 0]), ax=ax, label=labels[0], linestyle='--', color=cm(3))
        #plot_fisher_ellipse(score_flats[r], mean=np.array([0, 0]), ax=ax, label=labels[1], linestyle=':', color=cm(2))

ax.set_ylabel(r"$\mu_2$")
ax.set_xlabel(r"$\mu_1$")
ax.set_xlim(-8,8)
ax.set_ylim(-8, 8)
ax.set_box_aspect(1)
#plt.legend()
